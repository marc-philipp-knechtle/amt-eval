# %% [markdown]
#     # 7 Results
# ##

# %%
## 7.3 Comparing frame output against other MPE models

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 20})

categories = ['Unet:XL', 'O&F-MAESTRO', 'bp-pretrained']
datasets = ['comparing', 'Trios', 'RWC']
values_comparing = [83.0, 61.0, 40.0]
values_trios = [86.0, 71.2, 58.9]
values_rwc = [73.0, 61.6, 28.3]

x = np.arange(len(categories))
width = 0.25

# x = ['Unet:XL', 'O&F-MAESTRO', 'bp-pretrained']
# y = [83.0, 61.0, 40.0]

fig, ax = plt.subplots(figsize=(10, 10))

colours = ['lightgray','plum','lightblue','lightblue','palegreen', 'khaki']
# plt.bar(x, y, color=['lightgray','plum','lightblue','lightblue','palegreen', 'khaki'], yerr=[20, 10, 8], capsize=5)
bars_comparing = ax.bar(x-width, values_comparing, width, label='Comparing Dataset', color='tab:blue')
bars_trios = ax.bar(x, values_trios, width, label='Trios Dataset', color='tab:orange')
bars_rwc = ax.bar(x + width, values_rwc, width, label='RWC Dataset', color='tab:green')

ax.set_xlabel('Models')
ax.set_ylabel('Raw Average Precision performance on Frame Level (%)')

ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()

# %% [markdown]
# ## 7.4 Comparing frame output against Note Tracking Output

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 20})

categories = ['Comparing', 'MuN', 'SWD', 'B10', 'PhA', 'CSD', 'Trios', 'RWC']
models = ['O&F-MAESTRO', 'bp-pretrained']

values_maestro_raw = [59.8, 54.1, 57.5, 77.9, 50.8, 68.0, 69.0, 57.7]
values_maestro_nt = [60.6, 59.4, 59.0, 75.4, 53.0, 59.4, 70.1, 58.9]

values_bp_raw = [47.0, 27.5, 47.1, 78.2, 31.5, 66.8, 57.7, 34.5]
values_bp_nt = [61.3, 54.4, 57.3, 77.7, 53.3, 77.9, 57.9, 54.1]

x = np.arange(len(categories))
width = 0.18

# x = ['Unet:XL', 'O&F-MAESTRO', 'bp-pretrained']
# y = [83.0, 61.0, 40.0]

fig, ax = plt.subplots(figsize=(25, 10))

ax.grid(axis='x', linestyle='--', linewidth=0.5)

colours = ['lightgray','plum','lightblue','lightblue','palegreen', 'khaki']
# plt.bar(x, y, color=['lightgray','plum','lightblue','lightblue','palegreen', 'khaki'], yerr=[20, 10, 8], capsize=5)
# bars_comparing = ax.bar(x-width, values_comparing, width, label='Comparing Dataset', color='tab:blue')
# bars_trios = ax.bar(x, values_trios, width, label='Trios Dataset', color='tab:orange')
# bars_rwc = ax.bar(x + width, values_rwc, width, label='RWC Dataset', color='tab:green')
bars_maestro_raw = ax.bar(x - 1.7 * width, values_maestro_raw, width, label='O&F-MAESTRO from Frame', color='darkblue')
bars_maestro = ax.bar(x - 0.7 * width, values_maestro_nt, width, label='O&F-MAESTRO from Decoding', color='cornflowerblue')

bars_bp_raw = ax.bar(x + 0.7 * width, values_bp_raw, width, label='bp-pretrained from Frame', color='darkred')
bars_bp = ax.bar(x + 1.7 * width, values_bp_nt, width, label='bp-pretrained from Decoding', color='coral')



ax.set_xlabel('Datasets')
ax.set_ylabel('Average Precision performance on Frame Level (%)')

ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 20})

categories = ['Comparing', 'MuN', 'SWD', 'B10', 'PhA', 'CSD', 'Trios', 'RWC']
models = ['O&F-MAESTRO', 'bp-pretrained']

values_maestro_raw = [40.0, 49.8, 34.7, 58.8, 45.0, 13.7, 59.4, 47.4]
values_maestro_nt = [44.5, 51.0, 43.3, 60.2, 47.9, 12.1, 66.5, 59.5]

values_bp_raw = [9.9, 9.1, 10.2, 23.8, 7.2, 3.1, 15.7, 8.1]
values_bp_nt = [32.5, 37.8, 36.3, 42.1, 39.7, 8.7, 49.6, 44.8]

assert len(values_maestro_raw) == len(values_maestro_nt) == len(values_bp_raw) == len(values_bp_nt)

x = np.arange(len(categories))
width = 0.18

# x = ['Unet:XL', 'O&F-MAESTRO', 'bp-pretrained']
# y = [83.0, 61.0, 40.0]

fig, ax = plt.subplots(figsize=(25, 10))

ax.grid(axis='x', linestyle='--', linewidth=0.5)

colours = ['lightgray','plum','lightblue','lightblue','palegreen', 'khaki']
# plt.bar(x, y, color=['lightgray','plum','lightblue','lightblue','palegreen', 'khaki'], yerr=[20, 10, 8], capsize=5)
# bars_comparing = ax.bar(x-width, values_comparing, width, label='Comparing Dataset', color='tab:blue')
# bars_trios = ax.bar(x, values_trios, width, label='Trios Dataset', color='tab:orange')
# bars_rwc = ax.bar(x + width, values_rwc, width, label='RWC Dataset', color='tab:green')
bars_maestro_raw = ax.bar(x - 1.7 * width, values_maestro_raw, width, label='O&F-MAESTRO from Frame', color='darkblue')
bars_maestro = ax.bar(x - 0.7 * width, values_maestro_nt, width, label='O&F-MAESTRO from Decoding', color='cornflowerblue')

bars_bp_raw = ax.bar(x + 0.7 * width, values_bp_raw, width, label='bp-pretrained from Frame', color='darkred')
bars_bp = ax.bar(x + 1.7 * width, values_bp_nt, width, label='bp-pretrained from Decoding', color='coral')



ax.set_xlabel('Datasets')
ax.set_ylabel('Onset F1 with Threshold Optimized (%)')

ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 20})

categories = ['Comparing', 'MuN', 'SWD', 'B10', 'PhA', 'CSD', 'Trios', 'RWC']
models = ['O&F-MAESTRO', 'bp-pretrained']

values_maestro_raw = [15.1, 22.4, 8.2, 39.1, 16.2, 1.4, 22.0, 23.0]
values_maestro_nt = [17.8, 23.3, 14.4, 38.1, 17.9, 0.2, 27.1, 33.0]

values_bp_raw = [3.7, 2.6, 2.6, 16.1, 2.7, 0.0, 7.5, 2.0]
values_bp_nt = [12.0, 15.3, 10.4, 19.1, 19.7, 0.0, 13.4, 13.6]

assert len(values_maestro_raw) == len(values_maestro_nt) == len(values_bp_raw) == len(values_bp_nt)

x = np.arange(len(categories))
width = 0.18

# x = ['Unet:XL', 'O&F-MAESTRO', 'bp-pretrained']
# y = [83.0, 61.0, 40.0]

fig, ax = plt.subplots(figsize=(25, 10))

ax.grid(axis='x', linestyle='--', linewidth=0.5)

colours = ['lightgray','plum','lightblue','lightblue','palegreen', 'khaki']
# plt.bar(x, y, color=['lightgray','plum','lightblue','lightblue','palegreen', 'khaki'], yerr=[20, 10, 8], capsize=5)
# bars_comparing = ax.bar(x-width, values_comparing, width, label='Comparing Dataset', color='tab:blue')
# bars_trios = ax.bar(x, values_trios, width, label='Trios Dataset', color='tab:orange')
# bars_rwc = ax.bar(x + width, values_rwc, width, label='RWC Dataset', color='tab:green')
bars_maestro_raw = ax.bar(x - 1.7 * width, values_maestro_raw, width, label='O&F-MAESTRO from Frame', color='darkblue')
bars_maestro = ax.bar(x - 0.7 * width, values_maestro_nt, width, label='O&F-MAESTRO from Decoding', color='cornflowerblue')

bars_bp_raw = ax.bar(x + 0.7 * width, values_bp_raw, width, label='bp-pretrained from Frame', color='darkred')
bars_bp = ax.bar(x + 1.7 * width, values_bp_nt, width, label='bp-pretrained from Decoding', color='coral')



ax.set_xlabel('Datasets')
ax.set_ylabel('Onset-Offset F1 with Threshold Optimized (%)')

ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['A', 'B', 'C', 'D', 'E']
y1 = np.array([5, 7, 10, 8, 6])
y2 = np.array([6, 8, 9, 7, 5])
y3 = np.array([4, 6, 8, 6, 4])

# Error values for each dataset
error1 = np.array([0.5, 0.7, 0.8, 0.6, 0.4])
error2 = np.array([0.6, 0.5, 0.7, 0.4, 0.5])
error3 = np.array([0.4, 0.6, 0.5, 0.5, 0.3])

# Plotting
x = np.arange(len(categories))  # Label locations
width = 0.25  # Width of the bars

fig, ax = plt.subplots(figsize=(10, 6))

# Plot each dataset with error bars
bars1 = ax.bar(x - width, y1, width, yerr=error1, label='Dataset 1', capsize=5)
bars2 = ax.bar(x, y2, width, yerr=error2, label='Dataset 2', capsize=5)
bars3 = ax.bar(x + width, y3, width, yerr=error3, label='Dataset 3', capsize=5)

# Add labels, title, and customize the plot
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Bar Chart with Multiple Error Bars')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.grid(True)
plt.show()
