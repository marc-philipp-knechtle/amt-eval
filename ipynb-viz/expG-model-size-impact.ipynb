# %%
ap_frame_before_decoding = {
    'MSBPC':        [78.6, 80.2, 81.4, 81.5, 72.9, 70.9, 63.7, ],
    'Non-Piano':    [71.6, 73.1, 74.9, 75.0, 63.8, 63.1, 54.8 ],
}

ap_frame_after_decoding = {
    'MSBPC':        [63.2, 66.5, 67.4, 69.4, 68.0, 65.5, 62.6, ],
    'Non-Piano':    [52.2, 53.2, 58.4, 58.4, 54.9, 54.8, 53.0, ],
}

onset_f1_before_decoding = {
    'MSBPC':        [24.0, 26.7, 33.0, 33.5, 29.5, 25.1, 20.7],
    'Non-Piano':    [18.2, 20.4, 24.9, 25.6, 23.8, 20.7, 17.3],
}

onset_f1_after_decoding = {
    'MSBPC':        [44.3, 50.6, 51.7, 54.0, 55.8, 53.8, 46.9],
    'Non-Piano':    [32.9, 37.0, 38.3, 41.5, 42.0, 42.6, 36.8],
}

onset_offset_f1_before_decoding = {
    'MSBPC':        [8.4, 10.4, 14.8, 14.9, 10.6, 8.5, 6.1, ],
    'Non-Piano':    [6.7, 7.8, 11.1, 11.1, 8.8, 7.5, 5.4, ],
}

onset_offset_f1_after_decoding = {
    'MSBPC':        [17.8, 22.5, 26.0, 28.0, 24.0, 22.7, 16.7, ],
    'Non-Piano':    [10.3, 12.6, 16.0, 17.7, 15.2, 14.9, 10.9 ],
}

# %%
# Evaluation AP Frame before decoding

from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['6', '10', '16', '24', '*48*', '72', '144']

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, ap_frame_before_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
# plt.plot(models_oaf, model_performance['Unseen-Non-Piano'], marker='*', color='deepskyblue', linestyle='-', label='Unseen Non-Piano Test Set')
plt.plot(models_oaf, ap_frame_before_decoding['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.ylim(50, 85)
plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Hyperparameter c ')
plt.ylabel('Frame AP before decoding (%)')
# Out:
# Text(0, 0.5, 'Frame AP before decoding (%)')

# %%
# Evaluation AP Frame decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['6', '10', '16', '24', '*48*', '72', '144']

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, ap_frame_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
# plt.plot(models_oaf, model_performance['Unseen-Non-Piano'], marker='*', color='deepskyblue', linestyle='-', label='Unseen Non-Piano Test Set')
plt.plot(models_oaf, ap_frame_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.ylim(50, 85)
plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Hyperparameter c ')
plt.ylabel('Frame AP after decoding (%)')
# Out:
# Text(0, 0.5, 'Frame AP after decoding (%)')

# %%
# Evaluation Onset F1 score

from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['6', '10', '16', '24', '*48*', '72', '144']

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, onset_f1_before_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
# plt.plot(models_oaf, model_performance['Unseen-Non-Piano'], marker='*', color='deepskyblue', linestyle='-', label='Unseen Non-Piano Test Set')
plt.plot(models_oaf, onset_f1_before_decoding['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.ylim(15, 60)
plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Hyperparameter c ')
plt.ylabel('Onset F1 before decoding(%)')
# Out:
# Text(0, 0.5, 'Onset F1 before decoding(%)')

# %%
# Evaluation Onset F1 score

from matplotlib import pyplot as plt
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['6', '10', '16', '24', '*48*', '72', '144']

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, onset_f1_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
# plt.plot(models_oaf, model_performance['Unseen-Non-Piano'], marker='*', color='deepskyblue', linestyle='-', label='Unseen Non-Piano Test Set')
plt.plot(models_oaf, onset_f1_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.ylim(30, 60)
plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Hyperparameter c ')
plt.ylabel('Onset F1 after decoding(%)')
# Out:
# Text(0, 0.5, 'Onset F1 after decoding(%)')

# %%
# Evaluation Onset F1 score

from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['6', '10', '16', '24', '*48*', '72', '144']

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, onset_offset_f1_before_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
# plt.plot(models_oaf, model_performance['Unseen-Non-Piano'], marker='*', color='deepskyblue', linestyle='-', label='Unseen Non-Piano Test Set')
plt.plot(models_oaf, onset_offset_f1_before_decoding['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.ylim(5, 35)
plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Hyperparameter c ')
plt.ylabel('Onset and offset F1 before decoding(%)')
# Out:
# Text(0, 0.5, 'Onset and offset F1 before decoding(%)')

# %%
# Evaluation Onset F1 score

from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['6', '10', '16', '24', '*48*', '72', '144']


plt.figure(figsize=(12, 10))
plt.plot(models_oaf, onset_offset_f1_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
# plt.plot(models_oaf, model_performance['Unseen-Non-Piano'], marker='*', color='deepskyblue', linestyle='-', label='Unseen Non-Piano Test Set')
plt.plot(models_oaf, onset_offset_f1_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.ylim(5, 30)
plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Hyperparameter c ')
plt.ylabel('Onset and offset F1 after decoding(%)')
# Out:
# Text(0, 0.5, 'Onset and offset F1 after decoding(%)')
