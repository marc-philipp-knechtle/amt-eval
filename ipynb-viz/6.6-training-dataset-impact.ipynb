# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['M', 'MB', 'MBP', 'MBPC', 'MBPCS']

# Lists performances for each of the models mentioned in models_oaf
perf_onset_raw_f1 = {
    'Mixed': [65.2, 64.2, 57.3, 55.0, 55.7],
    'RWC+TRI': [55.6, 53.9, 51.8, 50.9, 50.5],
    'Non-Piano': [57.4, 55.9, 50.8, 50.1, 46.2],
    'MuN': [70.0, 66.5, 60.6, 59.3, 52.2],
    'B10': [71.1, 69.7, 66.5, 63.0, 61.5],
    'PhA': [61.8, 58.1, 49.1, 50.1, 50.4],
    'CSD': [71.1, 70.0, 76.6, 53.9, 49.6],
    'SWD': [59.4, 60.3, 47.9, 51.4, 59.0]
}

plt.figure(figsize=(14, 10))
plt.plot(models_oaf, perf_onset_raw_f1['Mixed'], marker='x', color='lightcoral', linestyle='-',
         label='Mixed Test Set')
plt.plot(models_oaf, perf_onset_raw_f1['RWC+TRI'], marker='*', color='firebrick', linestyle='-',
         label='RWC+TRI Test Set')
plt.plot(models_oaf, perf_onset_raw_f1['Non-Piano'], marker='o', color='darkred', linestyle='-',
         label='Non-Piano Mixed Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('AP (%)')
# Out:
# Text(0, 0.5, 'AP (%)')

# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['M', 'MB', 'MBP', 'MBPC', 'MBPCS']

# Lists performances for each of the models mentioned in models_oaf
perf_onset_raw_f1 = {
    'Mixed': [65.2, 64.2, 57.3, 55.0, 55.7],
    'RWC+TRI': [55.6, 53.9, 51.8, 50.9, 50.5],
    'Non-Piano': [57.4, 55.9, 50.8, 50.1, 46.2],
    'MuN': [70.0, 66.5, 60.6, 59.3, 52.2],
    'B10': [71.1, 69.7, 66.5, 63.0, 61.5],
    'PhA': [61.8, 58.1, 49.1, 50.1, 50.4],
    'CSD': [71.1, 70.0, 76.6, 53.9, 49.6],
    'SWD': [59.4, 60.3, 47.9, 51.4, 59.0]
}

plt.figure(figsize=(14, 10))

plt.plot(models_oaf, perf_onset_raw_f1['MuN'], marker='o', color='darkkhaki', linestyle='-.', label='MuN')
plt.plot(models_oaf, perf_onset_raw_f1['B10'], marker='o', color='plum', linestyle='-.', label='B10')
plt.plot(models_oaf, perf_onset_raw_f1['PhA'], marker='o', color='slategrey', linestyle='-.', label='PhA')
plt.plot(models_oaf, perf_onset_raw_f1['CSD'], marker='o', color='dodgerblue', linestyle='-.', label='CSD')
plt.plot(models_oaf, perf_onset_raw_f1['SWD'], marker='o', color='springgreen', linestyle='-.', label='SWD')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('AP (%)')
# Out:
# Text(0, 0.5, 'AP (%)')

# %%
# Evaluation Onset Raw F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['M', 'MB', 'MBP', 'MBPC', 'MBPCS']

# Lists performances for each of the models mentioned in models_oaf
perf_onset_raw_f1 = {
    'Mixed': [21.7, 23.0, 21.9, 20.1, 23.8],
    'RWC+TRI': [25.9, 24.7, 23.1, 22.3, 23.3],
    'Non-Piano': [23.0, 26.2, 23.5, 23.4, 23.3],
    'MuN': [29.3, 26.6, 26.5, 25.1, 24.6],
    'B10': [21.9, 36.2, 38.5, 30.8, 32.7],
    'PhA': [32.5, 35.0, 25.4, 28.3, 29.2],
    'CSD': [11.2, 10.0, 11.2, 4.0, 3.3],
    'SWD': [18.4, 17.7, 14.3, 14.2, 22.9]
}

plt.figure(figsize=(14, 10))
plt.plot(models_oaf, perf_onset_raw_f1['Mixed'], marker='x', color='lightcoral', linestyle='-',
         label='Mixed Test Set')
plt.plot(models_oaf, perf_onset_raw_f1['RWC+TRI'], marker='*', color='firebrick', linestyle='-',
         label='RWC+TRI Test Set')
plt.plot(models_oaf, perf_onset_raw_f1['Non-Piano'], marker='o', color='darkred', linestyle='-',
         label='Non-Piano Mixed Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('F1 (%)')
# Out:
# Text(0, 0.5, 'F1 (%)')

# %%
# Evaluation Onset Raw F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['M', 'MB', 'MBP', 'MBPC', 'MBPCS']

# Lists performances for each of the models mentioned in models_oaf
perf_onset_raw_f1 = {
    'Mixed': [21.7, 23.0, 21.9, 20.1, 23.8],
    'RWC+TRI': [25.9, 24.7, 23.1, 22.3, 23.3],
    'Non-Piano': [23.0, 26.2, 23.5, 23.4, 23.3],
    'MuN': [29.3, 26.6, 26.5, 25.1, 24.6],
    'B10': [21.9, 36.2, 38.5, 30.8, 32.7],
    'PhA': [32.5, 35.0, 25.4, 28.3, 29.2],
    'CSD': [11.2, 10.0, 11.2, 4.0, 3.3],
    'SWD': [18.4, 17.7, 14.3, 14.2, 22.9]
}

plt.figure(figsize=(14, 10))

plt.plot(models_oaf, perf_onset_raw_f1['MuN'], marker='o', color='darkkhaki', linestyle='-.', label='MuN')
plt.plot(models_oaf, perf_onset_raw_f1['B10'], marker='o', color='plum', linestyle='-.', label='B10')
plt.plot(models_oaf, perf_onset_raw_f1['PhA'], marker='o', color='slategrey', linestyle='-.', label='PhA')
plt.plot(models_oaf, perf_onset_raw_f1['CSD'], marker='o', color='dodgerblue', linestyle='-.', label='CSD')
plt.plot(models_oaf, perf_onset_raw_f1['SWD'], marker='o', color='springgreen', linestyle='-.', label='SWD')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('F1 (%)')
# Out:
# Text(0, 0.5, 'F1 (%)')
