# %%
oaf_perf_ap_frame = {
    'MSBPC':        [65.2, 45.7, 55.3, 60.3, 66.9, 64.7, ],
    'Unseen':       [66.3, 49.1, 57.8, 62.1, 46.1, 73.7, ],
    'Non-Piano':    [65.9, 48.8, 60.5, 60.6, 69.2, 66.4, ],
}

bp_perf_ap_frame = {
    'MSBPC':        [73.9, 74.0, 74.9, 75.3, 75.0, 74.9, ],
    'Unseen':       [74.7, 74.5, 75.2, 74.8, 75.4, 75.4, ],
    'Non-Piano':    [83.6, 83.9, 84.1, 84.5, 84.5, 84.4, ],
}

oaf_onset_f1 = {
    'MSBPC':        [44.5, 30.2, 43.8, 48.5, 48.2, 52.1, ],
    'Unseen':       [61.5, 36.1, 54.0, 50.2, 56.1, 59.0, ],
    'Non-Piano':    [40.2, 34.9, 44.7, 42.9, 43.9, 44.2, ],
}

bp_onset_f1 = {
    'MSBPC':        [35.0, 37.3, 37.6, 36.9, 37.5, 38.1, ],
    'Unseen':       [49.6, 57.7, 50.2, 48.7, 49.1, 50.5, ],
    'Non-Piano':    [30.7, 36.7, 38.0, 38.7, 38.6, 38.9, ],
}

oaf_onset_offset_f1 = {
    'MSBPC':        [17.8, 10.5, 17.0, 21.1, 22.3, 24.7, ],
    'Unseen':       [33.1, 10.4, 18.3, 18.9, 19.9, 25.0],
    'Non-Piano':    [17.1, 15.7, 21.6, 23.8, 24.2, 25.0 ],
}

bp_onset_offset_f1 = {
    'MSBPC':        [12.0, 14.1, 14.1, 14.9, 14.5, 14.6, ],
    'Unseen':       [13.4, 17.0, 17.2, 17.5, 17.2, 17.0, ],
    'Non-Piano':    [11.0, 22.1, 22.5, 23.7, 22.6, 23.2 ],
}

# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['baseline', 'mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']


plt.figure(figsize=(13, 10))
plt.plot(models_oaf, oaf_perf_ap_frame['MSBPC'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, oaf_perf_ap_frame['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, oaf_perf_ap_frame['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('OaF Models')
plt.ylabel('Frame AP after decoding (%)')

plt.ylim(45, 87)
# Out:
# (45.0, 87.0)

# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['baseline', 'mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

plt.figure(figsize=(13, 10))
plt.plot(models_oaf, bp_perf_ap_frame['MSBPC'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, bp_perf_ap_frame['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, bp_perf_ap_frame['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('BP Models')
plt.ylabel('Frame AP after decoding (%)')

plt.ylim(45, 87)
# Out:
# (45.0, 87.0)

# %%
# Evaluation Onset F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['baseline', 'mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

plt.figure(figsize=(13, 10))
plt.plot(models_oaf, oaf_onset_f1['MSBPC'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, oaf_onset_f1['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, oaf_onset_f1['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('OaF Models')
plt.ylabel('Onset F1 after decoding (%)')

plt.ylim(25, 60)
# Out:
# (25.0, 60.0)

# %%
# Evaluation Onset F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['baseline', 'mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']


plt.figure(figsize=(13, 10))
plt.plot(models_oaf, bp_onset_f1['MSBPC'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, bp_onset_f1['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, bp_onset_f1['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('BP Models')
plt.ylabel('Onset F1 after decoding (%)')

plt.ylim(25, 60)
# Out:
# (25.0, 60.0)

# %%
# Evaluation Onset Offset F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['baseline', 'mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

plt.figure(figsize=(13, 10))
plt.plot(models_oaf, oaf_onset_offset_f1['MSBPC'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, oaf_onset_offset_f1['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, oaf_onset_offset_f1['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')


plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('OaF Models')
plt.ylabel('Onset and Offset F1 after decoding (%)')

plt.ylim(10, 30)
# Out:
# (10.0, 30.0)

# %%
# Evaluation Onset Offset F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['baseline', 'mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']


plt.figure(figsize=(13, 10))
plt.plot(models_oaf, bp_onset_offset_f1['MSBPC'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, bp_onset_offset_f1['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, bp_onset_offset_f1['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('BP Models')
plt.ylabel('Onset and Offset F1 after decoding (%)')

plt.ylim(10, 30)
# Out:
# (10.0, 30.0)
