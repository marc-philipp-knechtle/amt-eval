# %%
# Evaluation AP Frame decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['16', '24', '48', '72', '144']

# Lists performances for each of the models mentioned in models_oaf
model_performance = {
    'Mixed': [63.3, 65.0, 63.8, 61.3, 58.5],
    'Unseen-Non-Piano': [48.7, 48.5, 45.2, 46.1, 45.2],
    'Non-Piano': [74.0, 70.3, 66.6, 66.1, 61.8],
    # 'MuN': [70.0, 66.5, 60.6, 59.3, 52.2],
    # 'B10': [71.1, 69.7, 66.5, 63.0, 61.5],
    # 'PhA': [61.8, 58.1, 49.1, 50.1, 50.4],
    # 'CSD': [71.1, 70.0, 76.6, 53.9, 49.6],
    # 'SWD': [59.4, 60.3, 47.9, 51.4, 59.0]
}

plt.figure(figsize=(14, 10))
plt.plot(models_oaf, model_performance['Mixed'], marker='x', color='lightcoral', linestyle='-',
         label='Mixed Test Set')
plt.plot(models_oaf, model_performance['Unseen-Non-Piano'], marker='*', color='deepskyblue', linestyle='-',
         label='Unseen Non-Piano Test Set')
plt.plot(models_oaf, model_performance['Non-Piano'], marker='o', color='orchid', linestyle='-',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.ylim(40, 80)
plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model size specified by hyperparameter c')
plt.ylabel('AP (%)')
# Out:
# Text(0, 0.5, 'AP (%)')

# %%
# Evaluation AP Frame decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['16', '24', '48', '72', '144']

# Lists performances for each of the models mentioned in models_oaf
model_performance = {
    'Mixed': [77.8, 78.3, 68.2, 66.0, 57.0],
    'Unseen-Non-Piano': [67.0, 66.7, 55.6, 55.8, 47.9],
    'Non-Piano': [86.3, 87.1, 71.1, 69.5, 54.5],
    # 'MuN': [70.0, 66.5, 60.6, 59.3, 52.2],
    # 'B10': [71.1, 69.7, 66.5, 63.0, 61.5],
    # 'PhA': [61.8, 58.1, 49.1, 50.1, 50.4],
    # 'CSD': [71.1, 70.0, 76.6, 53.9, 49.6],
    # 'SWD': [59.4, 60.3, 47.9, 51.4, 59.0]
}

plt.figure(figsize=(14, 10))
plt.plot(models_oaf, model_performance['Mixed'], marker='x', color='lightcoral', linestyle='-',
         label='Mixed Test Set')
plt.plot(models_oaf, model_performance['Unseen-Non-Piano'], marker='*', color='deepskyblue', linestyle='-',
         label='Unseen Non-Piano Test Set')
plt.plot(models_oaf, model_performance['Non-Piano'], marker='o', color='orchid', linestyle='-',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.ylim(40, 80)
plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model size specified by hyperparameter c')
plt.ylabel('Onset Raw F1 (%)')
# Out:
# Text(0, 0.5, 'Frame Raw F1 (%)')
