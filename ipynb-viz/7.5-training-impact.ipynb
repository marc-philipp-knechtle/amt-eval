# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 20})

metrics = ['AP-raw', 'AP-decoded', 'F1-note']
model_sizes_oaf = ['baseline', 'S', 'M']
model_sizes_bp = ['baseline', 'S', 'M', 'L']
comparing_perf_oaf = {
    'AP-raw': [61.0, 55.7, 59.6],
    'AP-decoded': [60.6, 47.9, 52.0],
    'F1-note': [44.5, 38.5, 43.1]
}
comparing_perf_bp = {
    'AP-raw': [40.0, 41.9, 41.2, 41.3],
    'AP-decoded': [61.3, 62.1, 62.7, 63.4],
    'F1-note': [32.5, 37.6, 38.0, 38.0]
}



plt.figure(figsize=(14, 10))
plt.plot(model_sizes_oaf, comparing_perf_oaf['AP-raw'], marker='x', color='lightcoral', label='OaF AP-raw')
plt.plot(model_sizes_oaf, comparing_perf_oaf['AP-decoded'], marker='*', color='firebrick', label='OaF AP-decoded')
plt.plot(model_sizes_oaf, comparing_perf_oaf['F1-note'], marker='o', color='darkred', label='OaF F1-note')

plt.plot(model_sizes_bp, comparing_perf_bp['AP-raw'], marker='x', label='BP AP-raw')
plt.plot(model_sizes_bp, comparing_perf_bp['AP-decoded'], marker='*', label='BP AP-decoded')
plt.plot(model_sizes_bp, comparing_perf_bp['F1-note'], marker='o', label='BP F1-note')

plt.plot()

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model dataset training size')
plt.ylabel('AP or F1 (%)')
# Out:
# Text(0, 0.5, 'AP or F1 (%)')

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 20})

# evaluation for AP-F raw

metrics = ['Mixed', 'RWC+TRI', 'Non-Piano']
model_sizes_oaf = ['baseline', 'S', 'M']
model_sizes_bp = ['baseline', 'S', 'M', 'L']
comparing_perf_oaf = {
    'Mixed': [61.0, 55.7, 59.6],
    'RWC+TRI': [62.4, 40.2, 52.6],
    'Non-Piano': [68.6, 71.1, 69.4]
}
comparing_perf_bp = {
    'Mixed': [40.0, 41.9, 41.2, 41.3],
    'RWC+TRI': [30.6, 30.8, 30.5, 30.4],
    'Non-Piano': [32.5, 37.6, 38.0, 38.0]
}



plt.figure(figsize=(14, 10))
plt.plot(model_sizes_oaf, comparing_perf_oaf['Mixed'], marker='x', color='lightcoral', linestyle='-', label='OaF Mixed')
plt.plot(model_sizes_oaf, comparing_perf_oaf['RWC+TRI'], marker='*', color='firebrick', linestyle='--', label='OaF RWC+TRI')
plt.plot(model_sizes_oaf, comparing_perf_oaf['Non-Piano'], marker='o', color='darkred', linestyle=':', label='OaF Non-Piano')

plt.plot(model_sizes_bp, comparing_perf_bp['Mixed'], marker='x', color='lightskyblue', linestyle='-', label='BP Mixed')
plt.plot(model_sizes_bp, comparing_perf_bp['RWC+TRI'], marker='*', color='royalblue', linestyle='--', label='BP RWC+TRI')
plt.plot(model_sizes_bp, comparing_perf_bp['Non-Piano'], marker='o', color='darkblue', linestyle=':', label='BP Non-Piano')

plt.plot()

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model dataset training size')
plt.ylabel('AP (%)')
# Out:
# Text(0, 0.5, 'AP (%)')

# %%
# AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 20})


metrics = ['Mixed', 'RWC+TRI', 'Non-Piano']
model_sizes_oaf = ['baseline', 'S', 'M']
model_sizes_bp = ['baseline', 'S', 'M', 'L']
comparing_perf_oaf = {
    'Mixed': [60.6, 47.9, 52.0],
    'RWC+TRI': [59.8, 37.5, 52.7],
    'Non-Piano': [64.1, 53.7, 54.0]
}
comparing_perf_bp = {
    'Mixed': [61.3, 62.1, 62.7, 63.4],
    'RWC+TRI': [54.4, 52.5, 52.8, 53.6],
    'Non-Piano': [73.3, 74.3, 73.9, 75.2]
}



plt.figure(figsize=(14, 10))
plt.plot(model_sizes_oaf, comparing_perf_oaf['Mixed'], marker='x', color='lightcoral', linestyle='-', label='OaF Mixed')
plt.plot(model_sizes_oaf, comparing_perf_oaf['RWC+TRI'], marker='*', color='firebrick', linestyle='--', label='OaF RWC+TRI')
plt.plot(model_sizes_oaf, comparing_perf_oaf['Non-Piano'], marker='o', color='darkred', linestyle=':', label='OaF Non-Piano')

plt.plot(model_sizes_bp, comparing_perf_bp['Mixed'], marker='x', color='lightskyblue', linestyle='-', label='BP Mixed')
plt.plot(model_sizes_bp, comparing_perf_bp['RWC+TRI'], marker='*', color='royalblue', linestyle='--', label='BP RWC+TRI')
plt.plot(model_sizes_bp, comparing_perf_bp['Non-Piano'], marker='o', color='darkblue', linestyle=':', label='BP Non-Piano')

plt.plot()

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model dataset training size')
plt.ylabel('AP (%)')
# Out:
# Text(0, 0.5, 'AP (%)')

# %%
# F1 Note

from matplotlib import pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 20})

metrics = ['Mixed', 'RWC+TRI', 'Non-Piano']
model_sizes_oaf = ['baseline', 'S', 'M']
model_sizes_bp = ['baseline', 'S', 'M', 'L']
comparing_perf_oaf = {
    'Mixed': [44.5, 38.5, 43.1],
    'RWC+TRI': [61.5, 40.5, 57.1],
    'Non-Piano': [38.2, 35.7, 37.5]
}
comparing_perf_bp = {
    'Mixed': [32.5, 37.6, 38.0, 38.0],
    'RWC+TRI': [45.2, 39.0, 41.2, 41.7],
    'Non-Piano': [28.1, 40.0, 38.5, 38.8]
}



plt.figure(figsize=(14, 10))
plt.plot(model_sizes_oaf, comparing_perf_oaf['Mixed'], marker='x', color='lightcoral', linestyle='-', label='OaF Mixed')
plt.plot(model_sizes_oaf, comparing_perf_oaf['RWC+TRI'], marker='*', color='firebrick', linestyle='--', label='OaF RWC+TRI')
plt.plot(model_sizes_oaf, comparing_perf_oaf['Non-Piano'], marker='o', color='darkred', linestyle=':', label='OaF Non-Piano')

plt.plot(model_sizes_bp, comparing_perf_bp['Mixed'], marker='x', color='lightskyblue', linestyle='-', label='BP Mixed')
plt.plot(model_sizes_bp, comparing_perf_bp['RWC+TRI'], marker='*', color='royalblue', linestyle='--', label='BP RWC+TRI')
plt.plot(model_sizes_bp, comparing_perf_bp['Non-Piano'], marker='o', color='darkblue', linestyle=':', label='BP Non-Piano')

plt.plot()

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model dataset training size')
plt.ylabel('F1 (%)')
# Out:
# Text(0, 0.5, 'F1 (%)')
