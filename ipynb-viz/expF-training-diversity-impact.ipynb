# %%
# Lists performances for each of the models mentioned in models_oaf

avg_prec_frame_raw = {
    'msbpc':        [61.0, 75.4, 76.8, 76.2, 76.1, 76.1],
    'Unseen':       [62.4, 68.8, 69.9, 68.1, 67.5, 67.0],
    'Non-Piano':    [52.1, 70.9, 72.1, 71.1, 70.9, 70.0],
    'MuN':          [53.6, 74.0, 75.7, 74.4, 75.3, 72.7],
    'B10':          [84.3, 89.9, 92.8, 93.4, 93.2, 91.6],
    'PhA':          [49.8, 71.9, 73.0, 72.7, 72.7, 72.3],
    'CSD':          [63.5, 78.9, 80.7, 82.8, 86.8, 83.1],
    'SWD':          [60.4, 72.1, 72.8, 71.3, 69.4, 72.7],
    'RWC':          [61.6, 68.4, 69.5, 67.5, 67.0, 66.5, ],
    'TRI':          [71.1, 74.4, 74.4, 75.0, 73.5, 72.6, ]
}


avg_prec_frame_decoded = {
    'msbpc':        [65.2, 69.6, 71.6, 67.6, 62.4, 66.6, ],
    'Unseen':       [66.3, 57.9, 58.2, 58.8, 51.9, 56.5, ],
    'Non-Piano':    [55.8, 58.8, 59.9, 61.1, 52.5, 54.5, ],
    'MuN':          [63.1, 69.8, 71.0, 67.9, 65.7, 67.7, ],
    'B10':          [80.1, 74.6, 80.1, 79.9, 66.1, 75.0, ],
    'PhA':          [58.5, 64.9, 66.0, 70.0, 67.3, 69.1, ],
    'CSD':          [62.5, 81.0, 83.9, 82.6, 60.7, 54.1, ],
    'SWD':          [64.5, 65.1, 66.6, 59.4, 59.2, 67.4, ],
    'RWC':          [65.4, 56.9, 57.3, 57.5, 51.2, 56.4, ],
    'TRI':          [76.2, 69.7, 69.1, 75.0, 60.1, 59.8, ]
}

f1_onset_after_decoding = {
    'msbpc':        [44.5, 39.8, 42.0, 44.9, 37.5, 53.4, ],
    'Unseen':       [61.5, 56.0, 51.3, 54.1, 44.2, 50.1, ],
    'Non-Piano':    [44.2, 37.9, 36.7, 40.7, 33.7, 39.2, ],
    'MuN':          [51.0, 62.1, 58.7, 62.4, 55.9, 59.4, ],
    'B10':          [60.2, 28.0, 75.1, 74.5, 63.9, 77.5, ],
    'PhA':          [47.9, 42.5, 34.3, 57.1, 38.6, 45.0, ],
    'CSD':          [12.1, 14.6, 18.6, 19.9, 24.1, 28.1, ],
    'SWD':          [43.3, 34.7, 30.5, 32.1, 21.5, 52.1, ],
    'RWC':          [61.0, 55.2, 50.6, 53.2, 44.5, 49.8, ],
    'TRI':          [66.9, 65.5, 58.9, 64.2, 41.3, 53.6, ]
}

f1_onset_offset_after_decoding = {
    'msbpc':        [17.8, 19.0, 22.9, 21.9, 18.0, 28.3, ],
    'Unseen':       [33.1, 22.4, 21.4, 20.8, 16.6, 19.8, ],
    'Non-Piano':    [16.8, 14.7, 17.2, 17.8, 13.6, 17.5, ],
    'MuN':          [23.3, 28.5, 28.4, 24.1, 22.8, 28.3, ],
    'B10':          [38.1, 21.2, 60.8, 58.8, 49.7, 59.0, ],
    'PhA':          [17.9, 17.3, 12.7, 28.1, 15.6, 19.9, ],
    'CSD':          [0.0, 8.2, 9.2, 11.3, 12.2, 12.4, ],
    'SWD':          [14.4, 15.4, 15.1, 13.6, 8.3, 26.5 ],
    'RWC':          [33.6, 21.5, 20.9, 19.9, 16.1, 19.1, ],
    'TRI':          [27.1, 33.0, 27.6, 31.8, 22.1, 28.5, ]
}
# f1_onset_raw = {
#     'msbpc': [19.6, 25.0, 28.3, 26.0, 25.6, 28.3],
#     'Unseen': [28.2, 30.9, 32.4, 28.8, 29.2, 28.7],
#     'Non-Piano': [23.9, 29.9, 30.0, 29.4, 28.3, 28.0],
#     'MuN': [18.6, 30.6, 33.3, 31.3, 32.1, 30.3],
#     'B10': [34.5, 34.6, 47.3, 44.4, 44.3, 41.7],
#     'PhA': [24.4, 41.5, 39.7, 38.9, 40.1, 39.3],
#     'CSD': [4.4, 10.4, 12.0, 13.5, 12.7, 13.3],
#     'SWD': [19.6, 20.7, 23.5, 20.0, 18.0, 26.4]
# }

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['Baseline', 'M', 'MB', 'MBP', 'MBPC', 'MBPCS']

plt.figure(figsize=(14, 10))
plt.plot(models_oaf, avg_prec_frame_decoded['msbpc'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, avg_prec_frame_decoded['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, avg_prec_frame_decoded['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')


plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('Frame Decoded AP (%)')

plt.ylim(45, 85)
# Out:
# (45.0, 85.0)

# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['Baseline', 'M', 'MB', 'MBP', 'MBPC', 'MBPCS']


plt.figure(figsize=(14, 10))

plt.plot(models_oaf, avg_prec_frame_decoded['MuN'], marker='o', color='darkkhaki', linestyle='-', label='MuN')
plt.plot(models_oaf, avg_prec_frame_decoded['B10'], marker='*', color='plum', linestyle='--', label='B10')
plt.plot(models_oaf, avg_prec_frame_decoded['PhA'], marker='.', color='slategrey', linestyle='--', label='PhA')
plt.plot(models_oaf, avg_prec_frame_decoded['CSD'], marker='P', color='dodgerblue', linestyle='--', label='CSD')
plt.plot(models_oaf, avg_prec_frame_decoded['SWD'], marker='x', color='springgreen', linestyle='-', label='SWD')
plt.plot(models_oaf, avg_prec_frame_decoded['RWC'], marker='+', color='salmon', linestyle=':', label='RWC')
plt.plot(models_oaf, avg_prec_frame_decoded['TRI'], marker='s', color='mediumpurple', linestyle=':', label='TRI')

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('Frame Decoded AP (%)')

plt.ylim(45, 85)
# Out:
# (45.0, 85.0)

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['Baseline', 'M', 'MB', 'MBP', 'MBPC', 'MBPCS']

plt.figure(figsize=(14, 10))
plt.plot(models_oaf, avg_prec_frame_raw['msbpc'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, avg_prec_frame_raw['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, avg_prec_frame_raw['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('Frame Raw AP (%)')

plt.ylim(48, 95)
# Out:
# (48.0, 95.0)

# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['Baseline', 'M', 'MB', 'MBP', 'MBPC', 'MBPCS']


plt.figure(figsize=(14, 10))

plt.plot(models_oaf, avg_prec_frame_raw['MuN'], marker='o', color='darkkhaki', linestyle='-', label='MuN')
plt.plot(models_oaf, avg_prec_frame_raw['B10'], marker='*', color='plum', linestyle='--', label='B10')
plt.plot(models_oaf, avg_prec_frame_raw['PhA'], marker='.', color='slategrey', linestyle='--', label='PhA')
plt.plot(models_oaf, avg_prec_frame_raw['CSD'], marker='P', color='dodgerblue', linestyle='--', label='CSD')
plt.plot(models_oaf, avg_prec_frame_raw['SWD'], marker='x', color='springgreen', linestyle='-', label='SWD')
plt.plot(models_oaf, avg_prec_frame_raw['RWC'], marker='+', color='salmon', linestyle=':', label='RWC')
plt.plot(models_oaf, avg_prec_frame_raw['TRI'], marker='s', color='mediumpurple', linestyle=':', label='TRI')

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('Frame Raw AP (%)')

plt.ylim(48, 95)
# Out:
# (48.0, 95.0)

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['Baseline', 'M', 'MB', 'MBP', 'MBPC', 'MBPCS']

plt.figure(figsize=(14, 10))
plt.plot(models_oaf, f1_onset_after_decoding['msbpc'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, f1_onset_after_decoding['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, f1_onset_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('Onset F1 after decoding (%)')

plt.ylim(10, 80)
# Out:
# (10.0, 80.0)

# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['Baseline', 'M', 'MB', 'MBP', 'MBPC', 'MBPCS']


plt.figure(figsize=(14, 10))

plt.plot(models_oaf, f1_onset_after_decoding['MuN'], marker='o', color='darkkhaki', linestyle='-', label='MuN')
plt.plot(models_oaf, f1_onset_after_decoding['B10'], marker='*', color='plum', linestyle='--', label='B10')
plt.plot(models_oaf, f1_onset_after_decoding['PhA'], marker='.', color='slategrey', linestyle='--', label='PhA')
plt.plot(models_oaf, f1_onset_after_decoding['CSD'], marker='P', color='dodgerblue', linestyle='--', label='CSD')
plt.plot(models_oaf, f1_onset_after_decoding['SWD'], marker='x', color='springgreen', linestyle='-', label='SWD')
plt.plot(models_oaf, f1_onset_after_decoding['RWC'], marker='+', color='salmon', linestyle=':', label='RWC')
plt.plot(models_oaf, f1_onset_after_decoding['TRI'], marker='s', color='mediumpurple', linestyle=':', label='TRI')

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('Onset F1 after decoding (%)')

plt.ylim(10, 80)
# Out:
# (10.0, 80.0)

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib


matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['Baseline', 'M', 'MB', 'MBP', 'MBPC', 'MBPCS']

plt.figure(figsize=(14, 10))
plt.plot(models_oaf, f1_onset_offset_after_decoding['msbpc'], marker='o', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, f1_onset_offset_after_decoding['Unseen'], marker='o', color='deepskyblue', linestyle=':',
         label='Unseen Test Set')
plt.plot(models_oaf, f1_onset_offset_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='--',
         label='Non-Piano Test Set')

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('Onset and Offset F1 after decoding (%)')

plt.ylim(0, 65)
# Out:
# (0.0, 65.0)

# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['Baseline', 'M', 'MB', 'MBP', 'MBPC', 'MBPCS']


plt.figure(figsize=(14, 10))

plt.plot(models_oaf, f1_onset_offset_after_decoding['MuN'], marker='o', color='darkkhaki', linestyle='-', label='MuN')
plt.plot(models_oaf, f1_onset_offset_after_decoding['B10'], marker='o', color='plum', linestyle='--', label='B10')
plt.plot(models_oaf, f1_onset_offset_after_decoding['PhA'], marker='o', color='slategrey', linestyle='--', label='PhA')
plt.plot(models_oaf, f1_onset_offset_after_decoding['CSD'], marker='o', color='dodgerblue', linestyle='--', label='CSD')
plt.plot(models_oaf, f1_onset_offset_after_decoding['SWD'], marker='o', color='springgreen', linestyle='-', label='SWD')
plt.plot(models_oaf, f1_onset_offset_after_decoding['RWC'], marker='o', color='salmon', linestyle=':', label='RWC')
plt.plot(models_oaf, f1_onset_offset_after_decoding['TRI'], marker='o', color='mediumpurple', linestyle=':', label='TRI')

plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('Model')
plt.ylabel('Onset F1 after decoding (%)')

plt.ylim(0,65)
# Out:
# (0.0, 65.0)
