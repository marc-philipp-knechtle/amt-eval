# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

# Lists performances for each of the models mentioned in models_oaf
perf_ap_frame_after_decoding = {
    'MSBPC':        [42.4, 51.8, 56.4, 62.9, 60.7],
    'Unseen':       [45.0, 52.9, 56.7, 41.9, 67.9],
    'Non-Piano':    [45.4, 56.7, 56.2, 65.2, 62.4, ],
    # 'MuN': [70.0, 66.5, 60.6, 59.3, 52.2],
    # 'B10': [71.1, 69.7, 66.5, 63.0, 61.5],
    # 'PhA': [61.8, 58.1, 49.1, 50.1, 50.4],
    # 'CSD': [71.1, 70.0, 76.6, 53.9, 49.6],
    # 'SWD': [59.4, 60.3, 47.9, 51.4, 59.0]
}

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, perf_ap_frame_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, perf_ap_frame_after_decoding['Unseen'], marker='*', color='deepskyblue', linestyle='-',
         label='Unseen Test Set')
plt.plot(models_oaf, perf_ap_frame_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='-',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('OaF Models')
plt.ylabel('Frame AP after decoding (%)')

plt.ylim(40, 70)
# Out:
# (40.0, 70.0)

# %%
# Evaluation AP decoded

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

# Lists performances for each of the models mentioned in models_oaf
perf_ap_frame_after_decoding = {
    'MSBPC':        [61.2, 62.6, 62.5, 62.7, 62.5, ],
    'Unseen':       [57.7, 59.0, 58.3, 58.9, 59.0, ],
    'Non-Piano':    [58.7, 59.8, 58.6, 59.5, 59.6, ],
    # 'MuN': [70.0, 66.5, 60.6, 59.3, 52.2],
    # 'B10': [71.1, 69.7, 66.5, 63.0, 61.5],
    # 'PhA': [61.8, 58.1, 49.1, 50.1, 50.4],
    # 'CSD': [71.1, 70.0, 76.6, 53.9, 49.6],
    # 'SWD': [59.4, 60.3, 47.9, 51.4, 59.0]
}

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, perf_ap_frame_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, perf_ap_frame_after_decoding['Unseen'], marker='*', color='deepskyblue', linestyle='-',
         label='Unseen Test Set')
plt.plot(models_oaf, perf_ap_frame_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='-',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('BP Models')
plt.ylabel('Frame AP after decoding (%)')

plt.ylim(40, 70)
# Out:
# (40.0, 70.0)

# %%
# Evaluation Onset F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

# Lists performances for each of the models mentioned in models_oaf
onset_f1_after_decoding = {
    'MSBPC':        [30.2, 43.8, 48.5, 48.2, 52.1, ],
    'Unseen':       [36.1, 54.0, 50.2, 56.1, 59.0, ],
    'Non-Piano':    [34.9, 44.7, 42.9, 43.9, 44.2, ],
}

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, onset_f1_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, onset_f1_after_decoding['Unseen'], marker='*', color='deepskyblue', linestyle='-',
         label='Unseen Test Set')
plt.plot(models_oaf, onset_f1_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='-',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('OaF Models')
plt.ylabel('Onset F1 after decoding (%)')

plt.ylim(25, 60)
# Out:
# (25.0, 60.0)

# %%
# Evaluation Onset F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

# Lists performances for each of the models mentioned in models_oaf
onset_f1_after_decoding = {
    'MSBPC':        [37.3, 37.6, 36.9, 37.5, 38.1, ],
    'Unseen':       [57.7, 50.2, 48.7, 49.1, 50.5, ],
    'Non-Piano':    [36.7, 36.8, 36.6, 36.5, 37.7, ],
}

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, onset_f1_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, onset_f1_after_decoding['Unseen'], marker='*', color='deepskyblue', linestyle='-',
         label='Unseen Test Set')
plt.plot(models_oaf, onset_f1_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='-',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('BP Models')
plt.ylabel('Onset F1 after decoding (%)')

plt.ylim(25, 60)
# Out:
# (25.0, 60.0)

# %%
# Evaluation Onset Offset F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

# Lists performances for each of the models mentioned in models_oaf
onset_offset_f1_after_decoding = {
    'MSBPC':        [13.1, 17.0, 21.1, 22.3, 24.7, ],
    'Unseen':       [15.9, 18.3, 18.9, 19.9, 25.0],
    'Non-Piano':    [15.7, 24.5, 23.8, 24.2, 25.0 ],
    # 'MuN': [70.0, 66.5, 60.6, 59.3, 52.2],
    # 'B10': [71.1, 69.7, 66.5, 63.0, 61.5],
    # 'PhA': [61.8, 58.1, 49.1, 50.1, 50.4],
    # 'CSD': [71.1, 70.0, 76.6, 53.9, 49.6],
    # 'SWD': [59.4, 60.3, 47.9, 51.4, 59.0]
}

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, onset_offset_f1_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, onset_offset_f1_after_decoding['Unseen'], marker='*', color='deepskyblue', linestyle='-',
         label='Unseen Test Set')
plt.plot(models_oaf, onset_offset_f1_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='-',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('OaF Models')
plt.ylabel('Onset and Offset F1 after decoding (%)')

plt.ylim(10, 30)
# Out:
# (10.0, 30.0)

# %%
# Evaluation Onset Offset F1

from matplotlib import pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams.update({'font.size': 20})

models_oaf = ['mixed-10', 'mixed-30', 'mixed-70', 'mixed-100', 'mixed-130']

# Lists performances for each of the models mentioned in models_oaf
onset_offset_f1_after_decoding = {
    'MSBPC':        [14.1, 14.1, 14.9, 14.5, 14.6, ],
    'Unseen':       [17.0, 17.2, 17.5, 17.2, 17.0, ],
    'Non-Piano':    [14.4, 14.7, 15.0, 14.6, 15.5, ],
}

plt.figure(figsize=(12, 10))
plt.plot(models_oaf, onset_offset_f1_after_decoding['MSBPC'], marker='x', color='lightcoral', linestyle='-',
         label='MSBPC Test Set')
plt.plot(models_oaf, onset_offset_f1_after_decoding['Unseen'], marker='*', color='deepskyblue', linestyle='-',
         label='Unseen Test Set')
plt.plot(models_oaf, onset_offset_f1_after_decoding['Non-Piano'], marker='o', color='orchid', linestyle='-',
         label='Non-Piano Test Set')

# plt.plot(models_oaf, perf_oaf['MuN'], marker='o', color='gray', linestyle=':', label='MuN')
# plt.plot(models_oaf, perf_oaf['CSD'], marker='o', color='lightgray', linestyle=':', label='CSD')
# plt.plot(models_oaf, perf_oaf['PhA'], marker='o', color='darkgrey', linestyle=':', label='PhA')

plt.plot()
plt.legend()
plt.grid(True, which="both", ls="--")
plt.xlabel('BP Models')
plt.ylabel('Onset and Offset F1 after decoding (%)')

plt.ylim(10, 30)
# Out:
# (10.0, 30.0)
